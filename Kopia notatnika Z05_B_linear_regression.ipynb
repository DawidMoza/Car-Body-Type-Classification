# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# W poniższym przykładzie posłużymy się zestawem danych reklamowych, obejmującym sprzedaż produktów i ich budżet reklamowy w trzech różnych mediach telewizyjnych, radiu, gazetach.

# %%
df_adv = pd.read_csv('Advertising.csv', index_col=0)
df_adv.head()
# Out:
#                                                                                                   400  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                                              NaN
# var ja                                                                                             ra
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...                                                NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...  d=0;d<b;d++)c[d]=a[d];return c}return[]};_.ma=...
# ua=function(a){return Array.isArray(a)?!!(sa(a)...  2)};wa=function(a){return null!==a&&"object"==...
#
#                                                                                                   500  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                                              NaN
# var ja                                                                                             sa
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...                                                NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...  b){Object.isFrozen(a)||(qa?a[qa]|=b:void 0!==a...
# ua=function(a){return Array.isArray(a)?!!(sa(a)...                                    configurable:!1
#
#                                                    700" nonce="yci8Q8x61lwQhMhQ64TRwA"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.SU_8YIUluc8.L.X.O/d=0/rs=AO0039sOh4sH4gfSy64Q7fgRByErbVICAQ" nonce="yci8Q8x61lwQhMhQ64TRwA"><script nonce="54YgUw2DmmR/ljbJODWbSQ">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                                              NaN
# var ja                                                                                             ua
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...                                                NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...                                       {Rd:{value:b
# ua=function(a){return Array.isArray(a)?!!(sa(a)...                                        writable:!1
#
#                                                                                  docs-fwds:"docs_sdf"  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                                              NaN
# var ja                                                                                             va
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...                                                NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...                                    configurable:!0
# ua=function(a){return Array.isArray(a)?!!(sa(a)...  enumerable:!1}};_.Ba=function(a){switch(typeof...
#
#                                                    docs-crs:"docs_crs_nfd"  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                   NaN
# var ja                                                                  wa
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...                     NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...             writable:!0
# ua=function(a){return Array.isArray(a)?!!(sa(a)...                     NaN
#
#                                                                                           docs-shdn:0  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                                              NaN
# var ja                                                                                             xa
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...                                                NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...  enumerable:!1}}))};sa=function(a){var b;qa?b=a...
# ua=function(a){return Array.isArray(a)?!!(sa(a)...                                                NaN
#
#                                                       docs-tfh:""  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                          NaN
# var ja                                                         Ea
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...            NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...  1);return a};
# ua=function(a){return Array.isArray(a)?!!(sa(a)...            NaN
#
#                                                    info_params:{}  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                          NaN
# var ja                                                         Fa
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...            NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...            NaN
# ua=function(a){return Array.isArray(a)?!!(sa(a)...            NaN
#
#                                                    docos-eddmh:false  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                             NaN
# var ja                                                            Da
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...               NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...               NaN
# ua=function(a){return Array.isArray(a)?!!(sa(a)...               NaN
#
#                                                    docs-eohmo:false  ...  \
# <!DOCTYPE html><html><head><meta name="google" ...                   ...
# try{                                                            NaN  ...
# var ja                                                           Ga  ...
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...              NaN  ...
# _.la=function(a){var b=a.length;if(0<b){for(var...              NaN  ...
# ua=function(a){return Array.isArray(a)?!!(sa(a)...              NaN  ...
#
#                                                    null.192 1.59 5.2  qr 189]  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                    NaN  NaN NaN NaN  NaN
# var ja                                                  NaN  NaN NaN NaN  NaN
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...      NaN  NaN NaN NaN  NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...      NaN  NaN NaN NaN  NaN
# ua=function(a){return Array.isArray(a)?!!(sa(a)...      NaN  NaN NaN NaN  NaN
#
#                                                    [[null.2 null.193 null.194  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                    NaN      NaN      NaN
# var ja                                                  NaN      NaN      NaN
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...      NaN      NaN      NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...      NaN      NaN      NaN
# ua=function(a){return Array.isArray(a)?!!(sa(a)...      NaN      NaN      NaN
#
#                                                    https://www.gstatic.com/og/_/js/k=og.qtm.en_US.Yq_fz1gGQMo.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTtjMF9WQwiK6CWnW4NDlTfNmKzm3w]]]]  \
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                                              NaN
# var ja                                                                                            NaN
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...                                                NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...                                                NaN
# ua=function(a){return Array.isArray(a)?!!(sa(a)...                                                NaN
#
#                                                    };this.gbar_=this.gbar_||{};(function(_){var window=this;
# <!DOCTYPE html><html><head><meta name="google" ...
# try{                                                                                              NaN
# var ja                                                                                            NaN
# _.ha=function(){return _.p("Safari")&&!(_.fa()|...                                                NaN
# _.la=function(a){var b=a.length;if(0<b){for(var...                                                NaN
# ua=function(a){return Array.isArray(a)?!!(sa(a)...                                                NaN
#
# [5 rows x 758 columns]

# %% [markdown]
# # Zad
# Proszę narysować dane za pomoca
# ```python
# sns.pairplot()
# ```

# %% [markdown]
# # Zad
# Proszę wyrysować dane za pomoca
# ```python
# sns.heatmap()
# ```

# %% [markdown]
# # Zadanie 1 - Konkurs
# Wykonaj model pozwalający przewidzieć zmienną "Sales" na podstawie innych zmiennych.

# %%
import statsmodels.formula.api as smf

# formula: response ~ predictor + predictor
est = smf.ols(formula='sales ~ I(newspaper)+I(TV)*I(radio)', data=df_adv).fit()
print((est.summary2()))
# Out:
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.967
# Dependent Variable: sales            AIC:                550.0809
# Date:               2020-03-26 06:55 BIC:                566.5725
# No. Observations:   200              Log-Likelihood:     -270.04
# Df Model:           4                F-statistic:        1466.
# Df Residuals:       195              Prob (F-statistic): 2.92e-144
# R-squared:          0.968            Scale:              0.89391
# -------------------------------------------------------------------
#                  Coef.   Std.Err.     t     P>|t|    [0.025  0.975]
# -------------------------------------------------------------------
# Intercept        6.7284    0.2533  26.5610  0.0000   6.2288  7.2280
# I(newspaper)     0.0014    0.0033   0.4383  0.6617  -0.0051  0.0079
# I(TV)            0.0191    0.0015  12.6330  0.0000   0.0161  0.0220
# I(radio)         0.0280    0.0091   3.0622  0.0025   0.0100  0.0460
# I(TV):I(radio)   0.0011    0.0001  20.6860  0.0000   0.0010  0.0012
# ------------------------------------------------------------------
# Omnibus:              126.161      Durbin-Watson:         2.216
# Prob(Omnibus):        0.000        Jarque-Bera (JB):      1123.463
# Skew:                 -2.291       Prob(JB):              0.000
# Kurtosis:             13.669       Condition No.:         18353
# ==================================================================
# * The condition number is large (2e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %%
import statsmodels 
statsmodels.__version__
# Out:
# '0.11.0'

# %%
import pandas 
pandas.__version__
# Out:
# '1.0.1'
